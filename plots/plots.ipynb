# %%
import pandas as pd
import matplotlib.pyplot as plt

csv_path = "sort_results.csv"

df = pd.read_csv(csv_path, sep=';')

df.head()
# Out:
#      type    n   algo  threshold  time_ms
# 0  random  500  merge          0        0
# 1  random  600  merge          0        0
# 2  random  700  merge          0        0
# 3  random  800  merge          0        0
# 4  random  900  merge          0        0

# %%
types = ["random", "reversed", "almost"]

for t in types:
    df_sub = df[(df["type"] == t) & (df["algo"] == "merge")]

    plt.figure(figsize=(8, 5))
    plt.plot(df_sub["n"], df_sub["time_ms"])
    plt.xlabel("Размер массива n")
    plt.ylabel("Время, мс")
    plt.title(f"Merge sort: {t} массивы")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
threshold = 30
types = ["random", "reversed", "almost"]

for t in types:
    df_sub = df[
        (df["type"] == t) &
        (df["algo"] == "hybrid") &
        (df["threshold"] == threshold)
    ]

    plt.figure(figsize=(8, 5))
    plt.plot(df_sub["n"], df_sub["time_ms"])
    plt.xlabel("Размер массива n")
    plt.ylabel("Время, мс")
    plt.title(f"Hybrid merge+insertion (threshold={threshold}): {t} массивы")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
threshold = 30
types = ["random", "reversed", "almost"]

for t in types:
    df_merge = df[(df["type"] == t) & (df["algo"] == "merge")]
    df_hybrid = df[
        (df["type"] == t) &
        (df["algo"] == "hybrid") &
        (df["threshold"] == threshold)
    ]

    plt.figure(figsize=(8, 5))
    plt.plot(df_merge["n"], df_merge["time_ms"], label="Merge sort")
    plt.plot(df_hybrid["n"], df_hybrid["time_ms"], label=f"Hybrid, threshold={threshold}")
    plt.xlabel("Размер массива n")
    plt.ylabel("Время, мс")
    plt.title(f"{t} массивы: merge vs hybrid (threshold={threshold})")
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()
